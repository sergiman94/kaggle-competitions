# %% [markdown]
# ## Import libraries

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt

print('libraries imported')
# Out:
# libraries imported

# %% [markdown]
# ## Load the data

# %%
train_data = pd.read_csv('./train.csv')
test_data = pd.read_csv('./test.csv')

print('data loaded')
# Out:
# data loaded

# %%
# split the data
train_dataset, val_dataset = train_test_split(train_data, test_size=0.3, random_state=42)
print('data splitted')
# Out:
# data splitted

# %%
# extract the labels
train_labels = train_dataset.pop('label')
val_labels = val_dataset.pop('label')
print('labels extracted')
# Out:
# labels extracted

# %%
# convert train labels to binary class matrix
train_labels = tf.keras.utils.to_categorical(train_labels.astype('int32'))
val_labels= tf.keras.utils.to_categorical(val_labels.astype('int32'))
print('labels converted')
# Out:
# labels converted

# %% [markdown]
# ## Data Exploration

# %%
# shape of the train_data
train_dataset.shape

## we have 29400 images and each image has 784 pixels (28, 28)
# Out:
# (29400, 784)

# %%
# shape of the val_data
val_dataset.shape

## we have 12600 images and each image has 784 pixels (28, 28)
# Out:
# (12600, 784)

# %%
# checking the max and min values in the data
train_dataset_np = train_dataset.to_numpy()
val_dataset_np = val_dataset.to_numpy()
test_data_np = test_data.to_numpy()

# training data
max_value = np.max(train_dataset_np)
min_value = np.min(train_dataset_np)
print('traning max value is: ' + str(max_value))
print('traning min value is: ' + str(min_value))

# validation data
max_value_val = np.max(val_dataset_np)
min_value_val = np.min(val_dataset_np)
print('validation max value is: ' + str(max_value_val))
print('validation min value is: ' + str(min_value_val))

# test data
max_value_test = np.max(test_data_np)
min_value_test = np.min(test_data_np)
print('test max value is: ' + str(max_value_test))
print('test min value is: ' + str(min_value_test))
# Out:
# traning max value is: 255
# traning min value is: 0
# validation max value is: 255
# validation min value is: 0
# test max value is: 255
# test min value is: 0

# %% [markdown]
# ## Data Preprocessing

# %%
# normalization
train_dataset = (train_dataset / 255.0).to_numpy()
val_dataset = (val_dataset / 255.0).to_numpy()
test_data = (test_data / 255.0).to_numpy()

print('data normalized')
# Out:
# data normalized

# %% [markdown]
# ## Build and compile the model

# %%
# build the model
input_dim = train_dataset.shape[1]
nb_classes = train_labels.shape[1]

model = Sequential([
    Dense(128, input_dim=input_dim, activation='relu'),
    Dropout(0.15),
    
    Dense(128, activation='relu'),
    Dropout(0.15),
    
    Dense(nb_classes, activation='softmax')
])
print('model built')
# Out:
# model built

# %%
# compile the model
model.compile(optimizer='adam', loss=tf.keras.losses.categorical_crossentropy, metrics=['accuracy'])
print('model compiled')
# Out:
# model compiled

# %% [markdown]
# ## Train the model

# %%
model.fit(train_dataset, train_labels, epochs=10, batch_size=16, validation_data=(val_dataset, val_labels))
# Out:
# Epoch 1/10
# 1838/1838 [==============================] - 4s 2ms/step - loss: 0.3388 - accuracy: 0.8978 - val_loss: 0.1566 - val_accuracy: 0.9510
# Epoch 2/10
# 1838/1838 [==============================] - 4s 2ms/step - loss: 0.1600 - accuracy: 0.9504 - val_loss: 0.1298 - val_accuracy: 0.9610
# Epoch 3/10
# 1838/1838 [==============================] - 4s 2ms/step - loss: 0.1223 - accuracy: 0.9623 - val_loss: 0.1232 - val_accuracy: 0.9619
# Epoch 4/10
# 1838/1838 [==============================] - 3s 2ms/step - loss: 0.1005 - accuracy: 0.9677 - val_loss: 0.1104 - val_accuracy: 0.9666
# Epoch 5/10
# 1838/1838 [==============================] - 4s 2ms/step - loss: 0.0864 - accuracy: 0.9715 - val_loss: 0.1017 - val_accuracy: 0.9690
# Epoch 6/10
# 1838/1838 [==============================] - 4s 2ms/step - loss: 0.0760 - accuracy: 0.9755 - val_loss: 0.1038 - val_accuracy: 0.9704
# Epoch 7/10
# 1838/1838 [==============================] - 3s 2ms/step - loss: 0.0664 - accuracy: 0.9784 - val_loss: 0.0997 - val_accuracy: 0.9704
# Epoch 8/10
# 1838/1838 [==============================] - 3s 2ms/step - loss: 0.0613 - accuracy: 0.9801 - val_loss: 0.1137 - val_accuracy: 0.9678
# Epoch 9/10
# 1838/1838 [==============================] - 3s 2ms/step - loss: 0.0547 - accuracy: 0.9813 - val_loss: 0.1100 - val_accuracy: 0.9701
# Epoch 10/10
# 1838/1838 [==============================] - 3s 2ms/step - loss: 0.0547 - accuracy: 0.9829 - val_loss: 0.1058 - val_accuracy: 0.9723

# %% [markdown]
# ## Predict and Submit

# %%
preds = model.predict(test_data)
# Out:
# 875/875 [==============================] - 1s 803us/step

# %%
norm_preds = [np.argmax(sublist) for sublist in preds]

# %%
def write_preds(preds, fname):
    pd.DataFrame({"ImageId": list(range(1,len(preds)+1)), "Label": preds}).to_csv(fname, index=False, header=True)

write_preds(norm_preds, "./submissions/submission_1.csv")
